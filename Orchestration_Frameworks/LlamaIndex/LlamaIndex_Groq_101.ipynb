# %% [markdown]
# ### Install the libraries

# %%
# !pip install llama-index llama-index-llms-groq llama-index-embeddings-huggingface

# %% [markdown]
# ### Import the libraries

# %%
from llama_index.core import(
    Settings, 
    VectorStoreIndex, 
    SimpleDirectoryReader
)
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.groq import Groq
from dotenv import load_dotenv
import os

# %% [markdown]
# ### Loading the GROQ and HF_TOKEN APIs

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Defining the LLM and Embedding Model

# %%
llm = Groq(model = "llama-3.1-8b-instant")
embed_model = HuggingFaceEmbedding(model_name = "BAAI/bge-small-en-v1.5")

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# ### Load the data for implementing RAG

# %%
documents = SimpleDirectoryReader("sample_data").load_data()

# %% [markdown]
# ### Index and Query the data

# %%
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What is the purpose of Sensors in Perception of an AI agent")
print(response)
# Out:
# 2026-02-19 10:34:55,301 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Sensors in Perception provide real-time information about the environment, allowing the AI agent to determine what to do next. They are essential for the AI agent to successfully explore its surroundings and take actions that lead to the achievement of its goals.
